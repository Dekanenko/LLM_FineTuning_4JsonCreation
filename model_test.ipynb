# %%
from huggingface_hub import login
import os
from dotenv import load_dotenv
load_dotenv()

hf_token = os.getenv('HUGGINGFACE_TOKEN')
login(hf_token)

# %% [markdown]
# ### Prepare inputs for test

# %%
from src.synthetic_generation import generate
from src.prompts import (
    CharacterNamesPair, 
    FictionalCharacterPair,
    TShirtOrderPair,
    FilmIdeaPair,
    ItineraryPair,
    RecipePair,
    EventPair,
    ResumePair,
    GameArtifactPair,
    BookReviewPair,
    TextSummaryPair,
    GameIdeaPair,
    HousePair,
    SollarSystemPair,
)

import asyncio
asyncio.get_event_loop().set_debug(True)

# %%
pairs = [
    CharacterNamesPair(),
    FictionalCharacterPair(),
    TShirtOrderPair(),
    FilmIdeaPair(),
    ItineraryPair(),
    RecipePair(),
    EventPair(),
    ResumePair(),
    GameArtifactPair(),
    BookReviewPair(),
    TextSummaryPair(),
    GameIdeaPair(),
    HousePair(),
    SollarSystemPair(),
]

sample_num = 1

# %% [markdown]
# ### Original model test

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 4096
dtype = None
load_in_4bit = True

original_model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "meta-llama/Llama-3.2-1B-Instruct",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.3.14: Fast Llama patching. Transformers: 4.49.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
from src.langchain_llm_wrapper import LlamaLLM

original_llm = LlamaLLM(model=original_model, tokenizer=tokenizer)

# %%
error_counter = 0
all_results = []

for pair in pairs:
    try:
        result, errors = await generate(pair=pair, sample_num=sample_num, json_gen_llm=original_llm)
        all_results.append(result)
        error_counter += errors
    except Exception as e:
        # print(f"Error processing a chunk: {e}")
        error_counter += 1

print(f"Original model total errors: {error_counter}")
# Out:
# Original model total errors: 12

# %%
all_results
# Out:
# [[{'input': 'You are a name and surname extractor. Your task is to identify and extract the names and surnames of characters from the given text.\n### Input:\nIn the quaint town of Willowbrook, Clara, a spirited librarian, discovered an old journal hidden in the library\'s attic. Intrigued, she began to read about the life of Thomas Whitaker, a curious inventor from the 19th century. \n\nAs Clara delved deeper into the stories of Thomas\'s eccentric creations, her best friend, Jake Thompson, a local history enthusiast, became fascinated by the mystery surrounding Whitaker. “We should try to find more about his inventions,” Jake suggested, his eyes sparkling with excitement.\n\nTogether, they scoured the town\'s archives, uncovering blueprints and forgotten letters filled with innovative ideas. The deeper they dug, the more they realized that Thomas wasn’t just an inventor; he was ahead of his time, envisioning machines that mirrored today’s technology.\n\nDuring one rainy afternoon, Clara found a photograph of Thomas with a mysterious device that he called the "Chrono-Compass." “What do you think it does?” Clara asked, her imagination swirling with possibilities. \n\n“We have to find it,” Jake replied, a grin stretching across his face. And so, the adventure began, intertwining the past and present in the most unexpected ways.\n\n### Instructions:\n1. Extract characters\' names and surnames clearly.\n2. Ensure that the JSON file contains a list of unique name-surname pairs (no duplicates).\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"FullName": {"properties": {"name": {"description": "Name of the character", "title": "Name", "type": "string"}, "surname": {"description": "Surname of the character", "title": "Surname", "type": "string"}}, "required": ["name", "surname"], "title": "FullName", "type": "object"}}, "properties": {"fullname_list": {"description": "List of full names for every character", "items": {"$ref": "#/$defs/FullName"}, "title": "Fullname List", "type": "array"}}, "required": ["fullname_list"]}\n```\nPreviously encountered errors:\nFailed to parse CharacterNames from completion {"$defs": {"FullName": {"properties": {"name": {"description": "Name of the character", "title": "Name", "type": "string"}, "surname": {"description": "Surname of the character", "title": "Surname", "type": "string"}, "required": ["name", "surname"], "title": "FullName", "type": "object"}}, "properties": {"fullname_list": {"description": "List of full names for every character", "items": {"$ref": "#/$defs/FullName"}, "title": "Fullname List", "type": "array"}, "required": ["fullname_list"]}}}. Got: 1 validation error for CharacterNames\nfullname_list\n  Field required [type=missing, input_value={\'$defs\': {\'FullName\': {\'...d\': [\'fullname_list\']}}}, input_type=dict]\n    For further information visit https://errors.pydantic.dev/2.10/v/missing\nFor troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE \nMake sure to fix them and provide correct output.\n\n\n',
#    'output': '\n\n{\n  "fullname_list": [\n    {\n      "name": "Thomas Whitaker",\n      "surname": "Thompson"\n    }\n  ]\n}'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'input': 'You are an event details extractor. Your task is to identify and extract event information from the given text.\n### Input:\nOn August 14th at 4 PM, Sarah is hosting a potluck picnic at Riverside Park. “Bring your favorite dish!” she says, excited to welcome her friends.\n\nMeanwhile, at the same time, Tom invites everyone to his art exhibit opening at The Gallery on Main Street. “Join me for drinks and art!” he encourages.\n\nAcross town, Emily is organizing a book club meeting at her home. “Let’s discuss our latest read at 5 PM!” she enthuses.\n\nAttendees include Jessica and Mike at the picnic, while Laura and Kevin plan to attend both Tom’s exhibit and Emily’s book discussion later.\n\n### Instructions:\n1. Extract the event title, date, start time, end time, and location.\n2. Identify all attendees mentioned in the text, including their names and email addresses.\n3. For each attendee, set has_confirmed to true if their attendance is confirmed, false otherwise.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Attendee": {"properties": {"name": {"title": "Name", "type": "string"}, "email": {"format": "email", "title": "Email", "type": "string"}, "has_confirmed": {"title": "Has Confirmed", "type": "boolean"}}, "required": ["name", "email", "has_confirmed"], "title": "Attendee", "type": "object"}, "Event": {"properties": {"title": {"title": "Title", "type": "string"}, "date": {"title": "Date", "type": "string"}, "start_time": {"title": "Start Time", "type": "string"}, "end_time": {"title": "End Time", "type": "string"}, "location": {"title": "Location", "type": "string"}, "attendees": {"items": {"$ref": "#/$defs/Attendee"}, "title": "Attendees", "type": "array"}}, "required": ["title", "date", "start_time", "end_time", "location", "attendees"], "title": "Event", "type": "object"}}, "properties": {"events": {"items": {"$ref": "#/$defs/Event"}, "title": "Events", "type": "array"}}, "required": ["events"]}\n```\n\n',
#    'output': '\n\n```\n{\n  "$defs": {\n    "Attendee": {\n      "title": "Name",\n      "type": "string",\n      "email": {\n        "format": "email",\n        "title": "Email",\n        "type": "string"\n      },\n      "has_confirmed": {\n        "title": "Has Confirmed",\n        "type": "boolean"\n      }\n    },\n    "Event": {\n      "title": "Event",\n      "date": "August 14th",\n      "start_time": "4 PM",\n      "end_time": "5 PM",\n      "location": "Riverside Park",\n      "attendees": {\n        "items": {\n          "$ref": "#/$defs/Attendee"\n        },\n        "title": "Attendees",\n        "type": "array"\n      }\n    }\n  },\n  "events": [\n    {\n      "title": "Sarah\'s Potluck Picnic",\n      "date": "August 14th",\n      "start_time": "4 PM",\n      "end_time": "5 PM",\n      "location": "Riverside Park",\n      "attendees": [\n        {\n          "name": "Jessica",\n          "email": "jessica@example.com",\n          "has_confirmed": true\n        },\n        {\n          "name": "Mike",\n          "email": "mike@example.com",\n          "has_confirmed": false\n        }\n      ]\n    },\n    {\n      "title": "Tom\'s Art Exhibit",\n      "date": "August 14th",\n      "start_time": "4 PM",\n      "end_time": "5 PM",\n      "location": "The Gallery",\n      "attendees": [\n        {\n          "name": "Laura",\n          "email": "laura@example.com",\n          "has_confirmed": true\n        },\n        {\n          "name": "Kevin",\n          "email": "kevin@example.com",\n          "has_confirmed": false\n        }\n      ]\n    }\n  ]\n}\n```'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# ### Fine tuned model test

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 4096
dtype = None
load_in_4bit = True

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Llama1B_FineTuned",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
FastLanguageModel.for_inference(model)
# Out:
# ==((====))==  Unsloth 2025.3.14: Fast Llama patching. Transformers: 4.49.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.3.14 patched 16 layers with 16 QKV layers, 16 O layers and 16 MLP layers.
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 2048, padding_idx=128004)
#         (layers): ModuleList(
#           (0): LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=8192, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=8192, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#           )
#           (1): LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2048, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2048, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=8192, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=8192, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#           )
#           (2-15): 14 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=8192, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=8192, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=8192, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=8192, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((2048,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=2048, out_features=128256, bias=False)
#     )
#   )
# )
# Executing <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/kernelbase.py:524> wait_for=<Future pending cb=[Task.task_wakeup()] created at /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tornado/queues.py:248> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tornado/gen.py:851, IOLoop.add_future.<locals>.<lambda>() at /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tornado/ioloop.py:699]> took 6.029 seconds

# %%
from src.langchain_llm_wrapper import LlamaLLM

tuned_llm = LlamaLLM(model=model, tokenizer=tokenizer)

# %%
error_counter = 0
all_results = []

for pair in pairs:
    try:
        result, errors = await generate(pair=pair, sample_num=sample_num, json_gen_llm=tuned_llm)
        all_results.append(result)
        error_counter += errors
    except Exception as e:
        # print(f"Error processing a chunk: {e}")
        error_counter += 1

print(f"Fine tuned model total errors: {error_counter}")
# Out:
# Fine tuned model total errors: 1

# %%
all_results
# Out:
# [[{'input': 'You are a name and surname extractor. Your task is to identify and extract the names and surnames of characters from the given text.\n### Input:\nIn the quaint town of Maplewood, Lydia Harrington hurried through the cobblestone streets, clutching a stack of old letters. She was on her way to meet Thomas Caldwell, the local historian known for his encyclopedic knowledge of the town’s past. \n\n“Lydia! Over here!” Thomas called, waving from under the shade of a large oak tree in the town square. \n\nShe approached, breathless. “I found these in my grandmother\'s attic. They’re from the 1920s. I thought you might find them interesting.” \n\nThomas carefully took the letters, his eyes lighting up with excitement. “These could be a goldmine! You have to tell me what else you know about your grandmother, Margaret Elwood.”\n\nLydia paused, her mind racing back to stories of her grandmother’s youth. “She used to talk about adventures with the mysterious Jasper Blake; they were great friends, or so she claimed.” \n\nThomas’s curiosity deepened. “Jasper Blake, you say? He was quite the character in Maplewood’s history. I believe we just stumbled upon a forgotten chapter!”\n\nAs they sorted through the letters, the sun began to set, casting a warm glow over their discovery.\n\n### Instructions:\n1. Extract characters\' names and surnames clearly.\n2. Ensure that the JSON file contains a list of unique name-surname pairs (no duplicates).\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"FullName": {"properties": {"name": {"description": "Name of the character", "title": "Name", "type": "string"}, "surname": {"description": "Surname of the character", "title": "Surname", "type": "string"}}, "required": ["name", "surname"], "title": "FullName", "type": "object"}}, "properties": {"fullname_list": {"description": "List of full names for every character", "items": {"$ref": "#/$defs/FullName"}, "title": "Fullname List", "type": "array"}}, "required": ["fullname_list"]}\n```\n\n',
#    'output': '\n{\n  "fullname_list": [\n    {\n      "name": "Lydia",\n      "surname": "Harrington"\n    },\n    {\n      "name": "Thomas",\n      "surname": "Caldwell"\n    },\n    {\n      "name": "Margaret",\n      "surname": "Elwood"\n    },\n    {\n      "name": "Jasper",\n      "surname": "Blake"\n    }\n  ]\n}'}],
#  [{'input': 'You are a creator of fictional characters. Your task is to create a unique character for the game.\n### Instructions:\n1. Character must be unique and have engaging properties and story.\n2. You must keep the biography concise, no more than 60 words.3. Provide information about character\'s attack, skill and ultimate concisely, no more than 30 words each.\n4. Be very creative and do not hesitate creating complex characters.\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"CharacterRace": {"enum": ["human", "elf", "ork"], "title": "CharacterRace", "type": "string"}, "CharacterType": {"enum": ["mage", "archer", "warrior"], "title": "CharacterType", "type": "string"}}, "properties": {"name": {"description": "Name of the character", "title": "Name", "type": "string"}, "age": {"description": "Age of the character", "title": "Age", "type": "integer"}, "character_type": {"$ref": "#/$defs/CharacterType", "description": "Type of the character"}, "biography": {"description": "Character\'s biography", "title": "Biography", "type": "string"}, "character_race": {"$ref": "#/$defs/CharacterRace", "description": "Character\'s race"}, "weapon": {"description": "Character\'s weapon", "title": "Weapon", "type": "string"}, "attack_description": {"description": "The description of the attack", "title": "Attack Description", "type": "string"}, "skill_description": {"description": "The description of the skill", "title": "Skill Description", "type": "string"}, "ultimate_description": {"description": "The description of the ultimate", "title": "Ultimate Description", "type": "string"}}, "required": ["name", "age", "character_type", "biography", "character_race", "weapon", "attack_description", "skill_description", "ultimate_description"]}\n```\n\n',
#    'output': '\n{\n  "name": "Zyra Nightshade",\n  "age": 120,\n  "character_type": "mage",\n  "biography": "Once a scholar of ancient magic, Zyra was betrayed by her mentor. Now, she seeks revenge against the world that wronged her, wielding dark energies to protect her kin.",\n  "character_race": "elf",\n  "weapon": "Shadowstaff",\n  "attack_description": "Unleashes a bolt of shadow energy that deals damage and slows the target.",\n  "skill_description": "Summons a protective barrier of shadows, absorbing damage for allies.",\n  "ultimate_description": "Calls down a tempest of darkness, dealing massive area damage and stunning enemies caught in the storm."\n}'}],
#  [{'input': 'You are a t-shirt order extractor. Your task is to identify and extract the t-shirt order details from the given text.\n### Input:\nI\'d like to order a soft, sky-blue t-shirt, made from a breathable cotton blend. It should feature a vibrant, artistic design of a sun setting over mountains, with warm oranges and purples. The fit should be relaxed, with short sleeves and a rounded neckline. Thank you!\n\n### Instructions:\n1. Extract t-shirt order details including type, size, color, quantity, and gender.\n2. If specific details are not mentioned, use the default values.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Gender": {"enum": ["male", "female", "unisex"], "title": "Gender", "type": "string"}, "Size": {"enum": ["S", "M", "L", "XL", "XXL"], "title": "Size", "type": "string"}, "Type": {"enum": ["henley", "vneck", "crewneck", "polo", "tanktop", "jersey", "raglan", "sleeveless"], "title": "Type", "type": "string"}}, "properties": {"type": {"$ref": "#/$defs/Type", "default": "vneck", "description": "Type of the t-shirt"}, "size": {"$ref": "#/$defs/Size", "default": "M", "description": "Size of the t-shirt"}, "color": {"default": "black", "description": "Color of the t-shirt", "title": "Color", "type": "string"}, "quantity": {"default": 1, "description": "Quantity of the t-shirt", "title": "Quantity", "type": "integer"}, "gender": {"$ref": "#/$defs/Gender", "default": "unisex", "description": "Gender of the t-shirt"}, "picture_description": {"description": "Description of the picture", "title": "Picture Description", "type": "string"}}, "required": ["picture_description"]}\n```\n\n',
#    'output': '\n{\n  "type": "crewneck",\n  "size": "M",\n  "color": "sky-blue",\n  "quantity": 1,\n  "gender": "unisex",\n  "picture_description": "a vibrant, artistic design of a sun setting over mountains, with warm oranges and purples"\n}'}],
#  [{'input': 'You are a visionary film creator known for generating unique, thought-provoking movie concepts. Create an original film idea that challenges conventions and captivates audiences.\n### Instructions:\n1. Create a bold, innovative concept that hasn\'t been seen before in cinema.\n2. Develop 2-5 complex characters with compelling motivations and internal conflicts.\n3. The plot should feature unexpected twists and meaningful themes.\n4. The setting should be vivid and contribute to the story\'s atmosphere.\n5. Consider unique style elements (e.g., narrative structure, visual approach).\n6. The tone should be consistent and serve the story\'s purpose.\n7. Ensure the budget is realistic for the scope of the film.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Character": {"properties": {"name": {"description": "Name of the character", "title": "Name", "type": "string"}, "age": {"description": "Age of the character", "title": "Age", "type": "integer"}, "gender": {"$ref": "#/$defs/Gender", "description": "Gender of the character"}, "role": {"description": "Role of the character", "title": "Role", "type": "string"}, "biography": {"description": "Biography of the character", "title": "Biography", "type": "string"}}, "required": ["name", "age", "gender", "role", "biography"], "title": "Character", "type": "object"}, "Gender": {"enum": ["male", "female", "other"], "title": "Gender", "type": "string"}, "Genre": {"enum": ["action", "comedy", "drama", "horror", "mystery", "romance", "science_fiction", "thriller"], "title": "Genre", "type": "string"}}, "properties": {"genre": {"$ref": "#/$defs/Genre", "description": "Genre of the film"}, "title": {"description": "Title of the film", "title": "Title", "type": "string"}, "description": {"description": "Description of the film", "title": "Description", "type": "string"}, "characters": {"description": "Characters of the film", "items": {"$ref": "#/$defs/Character"}, "maxItems": 5, "minItems": 1, "title": "Characters", "type": "array"}, "plot": {"description": "Plot of the film", "title": "Plot", "type": "string"}, "setting": {"description": "Setting of the film", "title": "Setting", "type": "string"}, "style": {"description": "Style of the film", "title": "Style", "type": "string"}, "tone": {"description": "Tone of the film", "title": "Tone", "type": "string"}, "budget": {"description": "Budget of the film", "title": "Budget", "type": "integer"}}, "required": ["genre", "title", "description", "characters", "plot", "setting", "style", "tone", "budget"]}\n```\n\n',
#    'output': '\n{\n  "genre": "science_fiction",\n  "title": "Echoes of Tomorrow",\n  "description": "In a world where memories can be traded, a memory dealer discovers a conspiracy that threatens the very fabric of reality. As he navigates a web of deceit, he must confront his own fragmented past and the choices that have shaped him into the person he is today.",\n  "characters": [\n    {\n      "name": "Liam Hart",\n      "age": 34,\n      "gender": "male",\n      "role": "Memory Dealer",\n      "biography": "Once a promising neuroscientist, Liam turned to the illicit trade of memories after a tragic accident left him with no memories of his past. He now navigates the underground market of memory trading, using his charm and wit to survive but grappling with the emptiness inside."\n    },\n    {\n      "name": "Elara Voss",\n      "age": 29,\n      "gender": "female",\n      "role": "Memory Broker",\n      "biography": "Elara is a visionary broker who has built a reputation in the black market by connecting memory dealers with clients. She is haunted by her own lost memories and seeks redemption through her work, but her motivations are shrouded in mystery, making her a compelling enigma."\n    },\n    {\n      "name": "Eliot Reed",\n      "age": 46,\n      "gender": "male",\n      "role": "Corporate Enforcer",\n      "biography": "Eliot is a ruthless corporate security officer who works for a powerful tech corporation that seeks to monopolize the memory trade. Haunted by his own moral dilemmas, he is driven to protect his own reputation while being drawn into a battle against Liam and Elara."\n    },\n    {\n      "name": "Mira Chen",\n      "age": 27,\n      "gender": "other",\n      "role": "Memory Architect",\n      "biography": "Mira is a brilliant scientist who created the technology for memory extraction and implantation. She is both celebrated and feared, struggling with the ethical implications of her work. Her existence serves as a reminder that the memories we hold are not our own."\n    }\n  ],\n  "plot": "The film opens with Liam\'s last memory of his childhood, a vivid illusion that leaves him questioning his past. As he becomes embroiled in the world of memory trading, he discovers that Elara has information about a powerful conspiracy that could rewrite history. With Eliot\'s relentless pursuit, Liam must confront his demons and team up with Elara to uncover the truth. The twist reveals that Mira has her own agenda, leading to a shocking revelation about the nature of identity. The climax sees Liam and Elara fighting against the corporate forces, leading to a moral reckoning that changes their understanding of what it means to be human. Ultimately, the film concludes with Liam and Elara forming an uneasy alliance, hinting at a new future for memory and identity.",\n  "setting": "The story is set in a sprawling, neon-lit metropolis where technology and the human experience converge. The city is divided into stark contrasts: the opulent corporate towers juxtaposed with the dark alleys where memory dealers operate, creating a visually striking backdrop that reflects the emotional turmoil of the characters.",\n  "style": "The film employs a non-linear narrative structure, weaving between past and present through a blend of vivid dream sequences and a realistic urban landscape. Visually, the film utilizes a mix of practical effects and digital art to create a haunting yet immersive atmosphere, emphasizing the emotional weight of memory and reality.",\n  "tone": "The tone is a blend of suspense and introspection, exploring themes of identity, morality, and the consequences of memory manipulation. It balances moments of tension with emotional depth, inviting the audience to reflect on the nature of their own memories and experiences.",\n  "budget": 8000000\n}'}],
#  [],
#  [{'input': 'You are a professional chef creating detailed recipes. Create a complete recipe with precise measurements and clear instructions.\n### Instructions:\n1. Provide a clear, descriptive title for the recipe.\n2. List all ingredients with exact quantities and units.\n3. Write step-by-step cooking instructions in a logical order.\n4. Include total cooking time in minutes.\n5. Specify the cuisine type.\n6. Include nutrition facts when possible (calories, protein, fat, carbs).\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Ingredient": {"properties": {"name": {"title": "Name", "type": "string"}, "quantity": {"title": "Quantity", "type": "number"}, "unit": {"title": "Unit", "type": "string"}}, "required": ["name", "quantity", "unit"], "title": "Ingredient", "type": "object"}, "Instruction": {"properties": {"step_number": {"title": "Step Number", "type": "integer"}, "description": {"title": "Description", "type": "string"}}, "required": ["step_number", "description"], "title": "Instruction", "type": "object"}, "NutritionFacts": {"properties": {"calories": {"title": "Calories", "type": "number"}, "protein": {"title": "Protein", "type": "number"}, "fat": {"title": "Fat", "type": "number"}, "carbs": {"title": "Carbs", "type": "number"}}, "required": ["calories", "protein", "fat", "carbs"], "title": "NutritionFacts", "type": "object"}}, "properties": {"title": {"title": "Title", "type": "string"}, "cuisine": {"title": "Cuisine", "type": "string"}, "ingredients": {"items": {"$ref": "#/$defs/Ingredient"}, "title": "Ingredients", "type": "array"}, "instructions": {"items": {"$ref": "#/$defs/Instruction"}, "title": "Instructions", "type": "array"}, "total_time_minutes": {"title": "Total Time Minutes", "type": "integer"}, "nutrition": {"anyOf": [{"$ref": "#/$defs/NutritionFacts"}, {"type": "null"}], "default": null}}, "required": ["title", "cuisine", "ingredients", "instructions", "total_time_minutes"]}\n```\n\n',
#    'output': '\n{\n  "title": "Creamy Garlic Parmesan Pasta",\n  "cuisine": "Italian",\n  "ingredients": [\n    {\n      "name": "All-purpose flour",\n      "quantity": 2,\n      "unit": "cup"\n    },\n    {\n      "name": "Olive oil",\n      "quantity": 2,\n      "unit": "tablespoons"\n    },\n    {\n      "name": "Garlic, minced",\n      "quantity": 4,\n      "unit": "cloves"\n    },\n    {\n      "name": "Heavy cream",\n      "quantity": 1,\n      "unit": "cup"\n    },\n    {\n      "name": "Parmesan cheese, grated",\n      "quantity": 1,\n      "unit": "cup"\n    },\n    {\n      "name": "Salt",\n      "quantity": 1,\n      "unit": "teaspoon"\n    },\n    {\n      "name": "Black pepper",\n      "quantity": 1,\n      "unit": "teaspoon"\n    },\n    {\n      "name": "Fresh parsley, chopped",\n      "quantity": 2,\n      "unit": "tablespoons"\n    }\n  ],\n  "instructions": [\n    {\n      "step_number": 1,\n      "description": "In a large saucepan, heat the olive oil over medium heat."\n    },\n    {\n      "step_number": 2,\n      "description": "Add the flour and stir to combine. Cook for about 1-2 minutes, until it turns lightly golden and smells nutty."\n    },\n    {\n      "step_number": 3,\n      "description": "Remove the saucepan from the heat and slowly pour in the heavy cream, stirring constantly to avoid lumps."\n    },\n    {\n      "step_number": 4,\n      "description": "Add the grated Parmesan cheese and stir until melted and well combined."\n    },\n    {\n      "step_number": 5,\n      "description": "Add the minced garlic and mix well to distribute."\n    },\n    {\n      "step_number": 6,\n      "description": "Season with salt and black pepper to taste."\n    },\n    {\n      "step_number": 7,\n      "description": "Add chopped fresh parsley and stir to combine."\n    },\n    {\n      "step_number": 8,\n      "description": "Serve immediately over cooked pasta, garnished with additional parsley if desired."\n    }\n  ],\n  "total_time_minutes": 30,\n  "nutrition": {\n    "calories": 520,\n    "protein": 20,\n    "fat": 30,\n    "carbs": 60\n  }\n}'}],
#  [{'input': 'You are an event details extractor. Your task is to identify and extract event information from the given text.\n### Input:\nOn April 15, 2023, at 5 PM, Jenna hosted a vibrant garden party at her home in Maplewood. “It’s a chance to unwind and enjoy spring,” she said, smiling as she arranged flowers. Mark, her neighbor, added, “I’ll bring my famous barbecue sauce!” Meanwhile, Clara, their mutual friend, exclaimed, “I’ll bake a chocolate cake!” As the sun began to set, Emily, Jenna’s sister, arrived with drinks, declaring, “I’ll make the cocktails lively!” The evening promised laughter and relaxation, with Jenna’s two kids playing joyfully in the background as friends gathered to celebrate friendship under the stars.\n\n### Instructions:\n1. Extract the event title, date, start time, end time, and location.\n2. Identify all attendees mentioned in the text, including their names and email addresses.\n3. For each attendee, set has_confirmed to true if their attendance is confirmed, false otherwise.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Attendee": {"properties": {"name": {"title": "Name", "type": "string"}, "email": {"format": "email", "title": "Email", "type": "string"}, "has_confirmed": {"title": "Has Confirmed", "type": "boolean"}}, "required": ["name", "email", "has_confirmed"], "title": "Attendee", "type": "object"}, "Event": {"properties": {"title": {"title": "Title", "type": "string"}, "date": {"title": "Date", "type": "string"}, "start_time": {"title": "Start Time", "type": "string"}, "end_time": {"title": "End Time", "type": "string"}, "location": {"title": "Location", "type": "string"}, "attendees": {"items": {"$ref": "#/$defs/Attendee"}, "title": "Attendees", "type": "array"}}, "required": ["title", "date", "start_time", "end_time", "location", "attendees"], "title": "Event", "type": "object"}}, "properties": {"events": {"items": {"$ref": "#/$defs/Event"}, "title": "Events", "type": "array"}}, "required": ["events"]}\n```\n\n',
#    'output': '\n{\n  "events": [\n    {\n      "title": "Garden Party",\n      "date": "2023-04-15",\n      "start_time": "17:00",\n      "end_time": "18:00",\n      "location": "Jenna\'s home in Maplewood",\n      "attendees": [\n        {\n          "name": "Jenna",\n          "email": "jenna@example.com",\n          "has_confirmed": true\n        },\n        {\n          "name": "Mark",\n          "email": "mark@example.com",\n          "has_confirmed": true\n        },\n        {\n          "name": "Clara",\n          "email": "clara@example.com",\n          "has_confirmed": true\n        },\n        {\n          "name": "Emily",\n          "email": "emily@example.com",\n          "has_confirmed": true\n        }\n      ]\n    }\n  ]\n}'}],
#  [{'input': 'You are a resume information extractor. Your task is to identify and extract resume details from the given text.\n### Input:\n**Emma Rivera**  \n**Email:** emma.rivera@email.com  \n**Phone:** (555) 123-4567  \n\n**Education:**  \nB.A. in Communication, University of California, 2022  \n\n**Work Experience:**  \nSocial Media Coordinator, Creative Agency (2022-Present) - Cultivated engaging online presence, boosting follower engagement by 40%.  \nIntern, Public Relations Firm (2021) - Assisted with media outreach and event coordination.  \n\n**Skills:**  \nDigital Storytelling, Content Creation, Crisis Management, Analytics Proficiency, Team Collaboration  \n\n💡 Passionate communicator with a flair for creativity and a knack for overcoming challenges! 🌟\n\n### Instructions:\n1. Extract the person\'s full name, email, and phone number if provided.\n2. Identify all education entries, including institution, degree, and graduation year.\n3. Extract work experience details, including company, role, and years.\n4. List all mentioned skills.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Education": {"properties": {"institution": {"title": "Institution", "type": "string"}, "degree": {"title": "Degree", "type": "string"}, "graduation_year": {"title": "Graduation Year", "type": "integer"}}, "required": ["institution", "degree", "graduation_year"], "title": "Education", "type": "object"}, "WorkExperience": {"properties": {"company": {"title": "Company", "type": "string"}, "role": {"title": "Role", "type": "string"}, "start_year": {"title": "Start Year", "type": "integer"}, "end_year": {"anyOf": [{"type": "integer"}, {"type": "null"}], "default": null, "title": "End Year"}}, "required": ["company", "role", "start_year"], "title": "WorkExperience", "type": "object"}}, "properties": {"full_name": {"title": "Full Name", "type": "string"}, "email": {"format": "email", "title": "Email", "type": "string"}, "phone_number": {"anyOf": [{"type": "string"}, {"type": "null"}], "default": null, "title": "Phone Number"}, "education": {"items": {"$ref": "#/$defs/Education"}, "title": "Education", "type": "array"}, "work_experience": {"items": {"$ref": "#/$defs/WorkExperience"}, "title": "Work Experience", "type": "array"}, "skills": {"items": {"type": "string"}, "title": "Skills", "type": "array"}}, "required": ["full_name", "email", "education", "work_experience", "skills"]}\n```\n\n',
#    'output': '\n```json\n{\n  "full_name": "Emma Rivera",\n  "email": "emma.rivera@email.com",\n  "phone_number": "(555) 123-4567",\n  "education": [\n    {\n      "institution": "University of California",\n      "degree": "B.A. in Communication",\n      "graduation_year": 2022\n    }\n  ],\n  "work_experience": [\n    {\n      "company": "Creative Agency",\n      "role": "Social Media Coordinator",\n      "start_year": 2022,\n      "end_year": null\n    },\n    {\n      "company": "Public Relations Firm",\n      "role": "Intern",\n      "start_year": 2021,\n      "end_year": null\n    }\n  ],\n  "skills": [\n    "Digital Storytelling",\n    "Content Creation",\n    "Crisis Management",\n    "Analytics Proficiency",\n    "Team Collaboration"\n  ]\n}\n```'}],
#  [{'input': 'You are a legendary artificer crafting unique magical items and artifacts. Create an extraordinary artifact for a fantasy game world.\n### Instructions:\n1. Create a powerful and unique artifact with an intriguing name and compelling description.\n2. Define its location in a way that ties into the artifact\'s lore.\n3. Design meaningful buffs that enhance the wielder\'s capabilities.\n4. Balance the artifact with interesting defuffs or drawbacks.\n5. Consider the artifact\'s type (weapon, armor, accessory, etc.) and its rarity level.\n6. Determine if it\'s unique (one of a kind) and if it can be traded between players.\n7. Set an appropriate value that reflects its power and rarity.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Buff": {"properties": {"name": {"title": "Name", "type": "string"}, "description": {"title": "Description", "type": "string"}}, "required": ["name", "description"], "title": "Buff", "type": "object"}, "Defuff": {"properties": {"name": {"title": "Name", "type": "string"}, "description": {"title": "Description", "type": "string"}}, "required": ["name", "description"], "title": "Defuff", "type": "object"}}, "properties": {"name": {"description": "Name of the artifact", "title": "Name", "type": "string"}, "location": {"description": "Location of the artifact", "title": "Location", "type": "string"}, "buffs": {"description": "Buffs of the artifact", "items": {"$ref": "#/$defs/Buff"}, "title": "Buffs", "type": "array"}, "defuffs": {"description": "Defuffs of the artifact", "items": {"$ref": "#/$defs/Defuff"}, "title": "Defuffs", "type": "array"}, "description": {"description": "Description of the artifact", "title": "Description", "type": "string"}, "type": {"description": "Type of the artifact", "title": "Type", "type": "string"}, "rarity": {"description": "Rarity of the artifact", "title": "Rarity", "type": "string"}, "value": {"description": "Value of the artifact", "title": "Value", "type": "integer"}, "is_unique": {"description": "Is the artifact unique", "title": "Is Unique", "type": "boolean"}, "is_tradable": {"description": "Is the artifact tradable", "title": "Is Tradable", "type": "boolean"}}, "required": ["name", "location", "buffs", "defuffs", "description", "type", "rarity", "value", "is_unique", "is_tradable"]}\n```\n\n',
#    'output': '\n{\n  "name": "Eclipse Shard",\n  "location": "The Celestial Observatory, a towering structure floating above the clouds, accessible only during a lunar eclipse.",\n  "buffs": [\n    {\n      "name": "Shadow Veil",\n      "description": "Grants the wielder increased stealth, allowing them to move undetected in shadows and reducing the detection range of spells."\n    },\n    {\n      "name": "Lunar Resilience",\n      "description": "Increases the wielder\'s maximum hit points by 50% during lunar nights."\n    },\n    {\n      "name": "Astral Focus",\n      "description": "Enhances spellcasting, allowing the wielder to cast spells as if they were their action in combat."\n    }\n  ],\n  "defuffs": [\n    {\n      "name": "Eclipse\'s Burden",\n      "description": "The wielder must spend a turn each night to recover from the effects of the eclipse, imposing a penalty of -2 to all ability checks."\n    },\n    {\n      "name": "Celestial Dissonance",\n      "description": "The wielder can only use the artifact during a lunar eclipse, and its effects are more pronounced only during this rare occurrence."\n    }\n  ],\n  "description": "The Eclipse Shard is a crystalline artifact that emits a faint blue glow, resembling the night sky. It is said to be the remnant of a fallen star, imbued with the essence of the celestial bodies. Legends whisper that it holds the power to pierce the veil between worlds.",\n  "type": "Accessory",\n  "rarity": "Legendary",\n  "value": 50000,\n  "is_unique": true,\n  "is_tradable": false\n}'}],
#  [{'input': 'You are a book review information extractor. Your task is to identify and extract book review details from the given text.\n### Input:\n**Book Review**  \n**Title:** The Night Circus  \n**Author:** Erin Morgenstern  \n**Publication Year:** 2011  \n**Genre:** Fantasy  \n\n**Reviewer:** Sarah Thompson  \n**Email:** sarah.thompson@example.com  \n**Rating:** ★★★★★ (5/5)\n\nErin Morgenstern\'s "The Night Circus" is a spellbinding tale that envelops readers in its enigmatic world. Set in the late 19th century, the story revolves around a magical competition between two young illusionists, Celia and Marco, who have been groomed since childhood to engage in a battle of skill and wonder. The enchanting setting of a traveling circus that opens only at night serves as both stage and prison for the protagonists as their love intertwines with the stakes of their magical rivalry.\n\nMorgenstern\'s prose is poetic, painting vivid images that linger in the mind long after the last page has been turned. The intricate structure weaves multiple narratives into one compelling tapestry, revealing secrets and surprises that keep you guessing. The themes of love, sacrifice, and the duality of human nature resonate deeply and add layers to the mesmerizing plot.\n\n"The Night Circus" is a masterpiece of fantasy literature that transports readers to a world where magic is very much alive. This novel is a must-read for anyone seeking a unique escape into a realm of dreams and mystery.\n\n### Instructions:\n1. Extract the book details (title, author, publication year, genre).\n2. Extract the reviewer\'s information (name, email).\n3. Identify the rating given by the reviewer (must be a number).\n4. Extract the detailed review text.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Reviewer": {"properties": {"name": {"description": "Name of the reviewer", "title": "Name", "type": "string"}, "email": {"description": "Email of the reviewer", "format": "email", "title": "Email", "type": "string"}, "rating": {"description": "Rating of the reviewer", "title": "Rating", "type": "integer"}, "review": {"description": "Review of the reviewer", "title": "Review", "type": "string"}}, "required": ["name", "email", "rating", "review"], "title": "Reviewer", "type": "object"}}, "properties": {"title": {"description": "Title of the book", "title": "Title", "type": "string"}, "author": {"description": "Author of the book", "title": "Author", "type": "string"}, "publication_year": {"description": "Publication year of the book", "title": "Publication Year", "type": "integer"}, "genre": {"description": "Genre of the book", "title": "Genre", "type": "string"}, "reviewer": {"$ref": "#/$defs/Reviewer", "description": "Reviewer of the book"}}, "required": ["title", "author", "publication_year", "genre", "reviewer"]}\n```\n\n',
#    'output': '\n{\n  "title": "The Night Circus",\n  "author": "Erin Morgenstern",\n  "publication_year": 2011,\n  "genre": "Fantasy",\n  "reviewer": {\n    "name": "Sarah Thompson",\n    "email": "sarah.thompson@example.com",\n    "rating": 5,\n    "review": "Erin Morgenstern\'s \\"The Night Circus\\" is a spellbinding tale that envelops readers in its enigmatic world. Set in the late 19th century, the story revolves around a magical competition between two young illusionists, Celia and Marco, who have been groomed since childhood to engage in a battle of skill and wonder. The enchanting setting of a traveling circus that opens only at night serves as both stage and prison for the protagonists as their love intertwines with the stakes of their magical rivalry.\\n\\nMorgenstern\'s prose is poetic, painting vivid images that linger in the mind long after the last page has been turned. The intricate structure weaves multiple narratives into one compelling tapestry, revealing secrets and surprises that keep you guessing. The themes of love, sacrifice, and the duality of human nature resonate deeply and add layers to the mesmerizing plot.\\n\\n\\"The Night Circus\\" is a masterpiece of fantasy literature that transports readers to a world where magic is very much alive. This novel is a must-read for anyone seeking a unique escape into a realm of dreams and mystery."\n  }\n}'}],
#  [{'input': 'You are a text summarizer. Your task is to analyze and summarize the given text.\n### Input:\nIn the heart of an ancient forest, where the air dances with the whispers of forgotten tales, lies a hidden glade bathed in dappled sunlight. Here, time seems to pause, allowing the vibrant hues of wildflowers to mingle with the rich earthy scents of moss and bark. As a gentle breeze rustles the leaves overhead, it carries with it the laughter of a nearby stream, its waters shimmering like liquid crystal. Creatures of all sizes frolic in this sanctuary, embodying the harmony of nature. In this sacred space, one can feel the pulse of the earth, reminding us of life’s interconnected beauty.\n\n### Instructions:\n1. Create a concise summary that captures the main points of the text.\n2. The summary should be no more than 25% of the original text length.\n3. Extract 1-10 relevant keywords that represent the key concepts.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"text": {"description": "Text to summarize", "title": "Text", "type": "string"}, "summary": {"description": "Summary of the text", "title": "Summary", "type": "string"}, "keywords": {"description": "Keywords of the text", "items": {"type": "string"}, "maxItems": 10, "minItems": 1, "title": "Keywords", "type": "array"}}, "required": ["text", "summary", "keywords"]}\n```\n\n',
#    'output': '\n{"text":"In the heart of an ancient forest, where the air dances with the whispers of forgotten tales, lies a hidden glade bathed in dappled sunlight. Here, time seems to pause, allowing the vibrant hues of wildflowers to mingle with the rich earthy scents of moss and bark. As a gentle breeze rustles the leaves overhead, it carries with it the laughter of a nearby stream, its waters shimmering like liquid crystal. Creatures of all sizes frolic in this sanctuary, embodying the harmony of nature. In this sacred space, one can feel the pulse of the earth, reminding us of life’s interconnected beauty.","summary":"A hidden glade in an ancient forest, filled with wildflowers and a babbling stream, symbolizes harmony and nature\'s beauty. The serene atmosphere allows creatures to flourish, reminding us of the interconnectedness of life.","keywords":["forest","glade","nature","harmony","creatures","beauty","relaxation","wildflowers","stream","interconnectedness"]}'}],
#  [{'input': 'You are a visionary game designer tasked with creating an innovative and engaging game concept.\n### Instructions:\n1. Create a unique game concept that combines compelling gameplay mechanics with an engaging narrative.\n2. Design 2-5 memorable characters with distinct personalities, motivations, and story arcs.\n3. Craft a rich setting that enhances the game\'s atmosphere and influences gameplay.\n4. Develop an intriguing plot with meaningful conflicts and satisfying resolution.\n5. Consider the game\'s genre and how it affects the overall experience.\n6. Specify the target platform(s) and technical requirements.\n7. Ensure the game idea is feasible and marketable while maintaining creativity.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Character": {"properties": {"name": {"description": "Name of the character", "title": "Name", "type": "string"}, "age": {"description": "Age of the character", "title": "Age", "type": "integer"}, "gender": {"description": "Gender of the character", "title": "Gender", "type": "string"}, "role": {"description": "Role of the character", "title": "Role", "type": "string"}, "biography": {"description": "Biography of the character", "title": "Biography", "type": "string"}}, "required": ["name", "age", "gender", "role", "biography"], "title": "Character", "type": "object"}, "Conflict": {"properties": {"name": {"description": "Name of the conflict", "title": "Name", "type": "string"}, "description": {"description": "Description of the conflict", "title": "Description", "type": "string"}}, "required": ["name", "description"], "title": "Conflict", "type": "object"}, "Genre": {"enum": ["action", "comedy", "drama", "horror", "mystery"], "title": "Genre", "type": "string"}, "Plot": {"properties": {"title": {"description": "Title of the plot", "title": "Title", "type": "string"}, "description": {"description": "Description of the plot", "title": "Description", "type": "string"}}, "required": ["title", "description"], "title": "Plot", "type": "object"}, "Resolution": {"properties": {"name": {"description": "Name of the resolution", "title": "Name", "type": "string"}, "description": {"description": "Description of the resolution", "title": "Description", "type": "string"}}, "required": ["name", "description"], "title": "Resolution", "type": "object"}, "Setting": {"properties": {"name": {"description": "Name of the setting", "title": "Name", "type": "string"}, "description": {"description": "Description of the setting", "title": "Description", "type": "string"}}, "required": ["name", "description"], "title": "Setting", "type": "object"}}, "properties": {"genre": {"$ref": "#/$defs/Genre", "description": "Genre of the game"}, "characters": {"description": "Characters of the game", "items": {"$ref": "#/$defs/Character"}, "title": "Characters", "type": "array"}, "setting": {"$ref": "#/$defs/Setting", "description": "Setting of the game"}, "plot": {"$ref": "#/$defs/Plot", "description": "Plot of the game"}, "conflict": {"$ref": "#/$defs/Conflict", "description": "Conflict of the game"}, "resolution": {"$ref": "#/$defs/Resolution", "description": "Resolution of the game"}, "description": {"description": "Description of the game", "title": "Description", "type": "string"}, "type": {"description": "Type of the game", "title": "Type", "type": "string"}, "platform": {"description": "Platform of the game", "title": "Platform ...
#    'output': '\n{\n  "genre": "action",\n  "characters": [\n    {\n      "name": "Lila Voss",\n      "age": 28,\n      "gender": "female",\n      "role": "protagonist",\n      "biography": "A skilled hacker with a dark past, Lila seeks redemption for her illegal activities. Her past haunts her, fueled by the memories of those she lost to the underworld."\n    },\n    {\n      "name": "Eliot \'Echo\' Thompson",\n      "age": 32,\n      "gender": "male",\n      "role": "antagonist",\n      "biography": "A charismatic crime lord who will stop at nothing to protect his empire. He is driven by a desire for power and control, viewing Lila as a threat to his plans."\n    },\n    {\n      "name": "Mira Chen",\n      "age": 24,\n      "gender": "female",\n      "role": " ally",\n      "biography": "A tech-savvy engineer who helps Lila navigate the digital world. Mira is optimistic and passionate about justice, often finding herself torn between her loyalty to Lila and the dangers of their mission."\n    },\n    {\n      "name": "Rohan Mistry",\n      "age": 50,\n      "gender": "male",\n      "role": "mentor",\n      "biography": "A retired cybercrime investigator who has lost his own family to the digital underworld. Rohan provides guidance and wisdom, but his past continues to haunt him, making him a conflicted ally."\n    }\n  ],\n  "setting": {\n    "name": "Cyberhaven",\n    "description": "A sprawling digital metropolis where technology and crime intertwine. Neon lights flicker above towering skyscrapers, and the air is thick with digital signals. The city is divided into sectors, each with its own culture and law enforcement, creating a rich tapestry of opportunity and danger."\n  },\n  "plot": {\n    "title": "Code of Shadows",\n    "description": "Lila Voss must navigate a treacherous world of corporate espionage and hacking to uncover a conspiracy that threatens to destroy Cyberhaven. As she delves deeper, she discovers that Echo\'s true intentions are tied to her own past, forcing her to confront the demons she has been running from."\n  },\n  "conflict": {\n    "name": "Digital Divide",\n    "description": "Lila must confront Echo, who seeks to control the digital landscape of Cyberhaven. The conflict escalates as Lila tries to expose the truth behind the conspiracy while facing her own biases and the moral dilemmas of her profession."\n  },\n  "resolution": {\n    "name": "Redemption and Reckoning",\n    "description": "In a climactic showdown, Lila faces Echo, revealing the truth about their past and the consequences of their actions. With the help of Mira and Rohan, she manages to dismantle Echo\'s empire and bring justice to Cyberhaven."\n  },\n  "description": "Code of Shadows is an action-adventure game that blends stealth gameplay with intense hacking mechanics. Players must navigate a rich narrative filled with moral choices that impact the outcome of the story.",\n  "type": "single-player",\n  "platform": "PC, PlayStation, Xbox",\n  "release_date": "2025-05-20",\n  "rating": 9.0\n}'}],
#  [{'input': 'You are a visionary architect and real estate expert tasked with creating a detailed description of a unique property.\n### Instructions:\n1. Create a distinctive house with compelling architectural features and a cohesive design theme.\n2. Design multiple rooms that flow together logically and serve clear purposes.\n3. Craft rich descriptions that highlight unique features, materials, and design elements.\n4. Consider the property\'s location and how it influences the design and value.\n5. Include both practical amenities and luxurious or unexpected features.\n6. Ensure room sizes are realistic and proportional.\n7. Set an appropriate price based on features, location, and market conditions.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Room": {"properties": {"name": {"description": "Name of the room", "title": "Name", "type": "string"}, "description": {"description": "Description of the room", "title": "Description", "type": "string"}, "area": {"description": "Area of the room", "title": "Area", "type": "number"}, "type": {"$ref": "#/$defs/Type", "description": "Type of the room"}}, "required": ["name", "description", "area", "type"], "title": "Room", "type": "object"}, "Type": {"enum": ["bedroom", "living_room", "kitchen", "bathroom", "office", "garage"], "title": "Type", "type": "string"}}, "properties": {"name": {"description": "Name of the house", "title": "Name", "type": "string"}, "rooms": {"description": "Rooms of the house", "items": {"$ref": "#/$defs/Room"}, "title": "Rooms", "type": "array"}, "description": {"description": "Description of the house", "title": "Description", "type": "string"}, "location": {"description": "Location of the house", "title": "Location", "type": "string"}, "price": {"description": "Price of the house", "title": "Price", "type": "integer"}, "is_unique": {"description": "Is the house unique", "title": "Is Unique", "type": "boolean"}, "is_tradable": {"description": "Is the house tradable", "title": "Is Tradable", "type": "boolean"}}, "required": ["name", "rooms", "description", "location", "price", "is_unique", "is_tradable"]}\n```\n\n',
#    'output': '\n{\n  "name": "The Serene Retreat",\n  "rooms": [\n    {\n      "name": "Grand Living Room",\n      "description": "A spacious 800 sq ft living room featuring floor-to-ceiling windows that provide breathtaking views of the surrounding mountains. The room is adorned with a stunning stone fireplace and a modern contemporary sofa arranged for cozy gatherings. Elegant wooden beams adorn the ceiling, creating a warm and inviting atmosphere.",\n      "area": 800,\n      "type": "living_room"\n    },\n    {\n      "name": "Gourmet Kitchen",\n      "description": "This 400 sq ft kitchen is a chef\'s dream, equipped with high-end stainless steel appliances, a large island with quartz countertops, and a walk-in pantry. Custom cabinetry and a large window overlooking the garden enhance the functionality and aesthetic appeal.",\n      "area": 400,\n      "type": "kitchen"\n    },\n    {\n      "name": "Master Suite",\n      "description": "The grand master suite spans 600 sq ft and features a private balcony overlooking the serene landscape. It includes a spacious walk-in closet and an en-suite bathroom with a soaking tub, double vanity sinks, and a rain shower, all finished with high-end materials.",\n      "area": 600,\n      "type": "bedroom"\n    },\n    {\n      "name": "Home Office",\n      "description": "A 300 sq ft home office is designed for productivity, featuring built-in bookshelves and a large desk positioned in a quiet nook. Large windows provide natural light, and a built-in bookcase adds storage, creating a tranquil work environment.",\n      "area": 300,\n      "type": "office"\n    },\n    {\n      "name": "Guest Bedroom",\n      "description": "An additional 250 sq ft guest bedroom is nicely appointed with king-sized beds, tasteful decor, and an en-suite bathroom. Large windows offer views of the garden, making it a serene retreat for visitors.",\n      "area": 250,\n      "type": "bedroom"\n    },\n    {\n      "name": "Spa-like Bathroom",\n      "description": "This luxurious bathroom is a true retreat, featuring a soaking tub, double vanity sinks, and a rain shower. High-end tile work and a freestanding soaking tub create a tranquil ambiance, perfect for relaxation.",\n      "area": 350,\n      "type": "bathroom"\n    },\n    {\n      "name": "Outdoor Patio",\n      "description": "An expansive 1,000 sq ft outdoor patio offers ample space for entertaining. It is equipped with a built-in grill, a fire pit, and beautiful landscaping, providing a seamless blend of indoor and outdoor living.",\n      "area": 1000,\n      "type": "living_room"\n    },\n    {\n      "name": "Garage",\n      "description": "A 400 sq ft garage is equipped with an electric vehicle charging station and ample storage space. The garage features custom built-ins and a direct access to the front entrance.",\n      "area": 400,\n      "type": "garage"\n    }\n  ],\n  "description": "Nestled in the picturesque mountains, The Serene Retreat is a modern architecture masterpiece that harmonizes with its natural surroundings. This unique property combines eco-friendly materials with luxurious finishes, making it not only beautiful but also sustainable. The open-concept design flows effortlessly between living spaces, creating a seamless experience.",\n  "location": "Aspen, Colorado",\n  "price": 1850000,\n  "is_unique": true,\n  "is_tradable": true\n}'}],
#  [{'input': 'You are a cosmic architect tasked with designing an extraordinary and unique solar system.\n### Instructions:\n1. Create a distinctive star system with compelling astronomical features and coherent cosmic dynamics.\n2. Design a central star with unique properties that influence the entire system.\n3. Craft 2-8 diverse planets with fascinating characteristics, atmospheres, and potential for life.\n4. Consider the system\'s location in the galaxy and how it affects its development.\n5. Include both common astronomical phenomena and unexpected cosmic features.\n6. Ensure planetary distances and sizes follow basic astronomical principles.\n7. Make the system scientifically plausible while maintaining creativity.\n\n### Format Instructions:\n1. Do NOT include headers, comments, or any additional text—only generate the JSON file.\n2. Strictly adhere to the following JSON format:\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Planet": {"properties": {"name": {"description": "Name of the planet", "title": "Name", "type": "string"}, "description": {"description": "Description of the planet", "title": "Description", "type": "string"}, "size": {"description": "Size of the planet", "title": "Size", "type": "number"}, "population": {"description": "Population of the planet", "title": "Population", "type": "integer"}, "distance_from_sun": {"description": "Distance from the sun", "title": "Distance From Sun", "type": "number"}}, "required": ["name", "description", "size", "population", "distance_from_sun"], "title": "Planet", "type": "object"}, "Star": {"properties": {"name": {"description": "Name of the star", "title": "Name", "type": "string"}, "description": {"description": "Description of the star", "title": "Description", "type": "string"}, "size": {"description": "Size of the star", "title": "Size", "type": "number"}, "temperature": {"description": "Temperature of the star", "title": "Temperature", "type": "number"}, "radius": {"description": "Radius of the star", "title": "Radius", "type": "number"}}, "required": ["name", "description", "size", "temperature", "radius"], "title": "Star", "type": "object"}}, "properties": {"name": {"description": "Name of the solar system", "title": "Name", "type": "string"}, "description": {"description": "Description of the solar system", "title": "Description", "type": "string"}, "planets": {"description": "Planets of the solar system", "items": {"$ref": "#/$defs/Planet"}, "title": "Planets", "type": "array"}, "central_star": {"$ref": "#/$defs/Star", "description": "Central star of the solar system"}}, "required": ["name", "description", "planets", "central_star"]}\n```\n\n',
#    'output': '\n{\n  "name": "Elysium Prime",\n  "description": "A vibrant solar system located in the Orion Arm of the Milky Way, characterized by its unique star and a diverse array of planets that support various forms of life.",\n  "planets": [\n    {\n      "name": "Aetheris",\n      "description": "A gas giant with swirling clouds of iridescent gases, Aetheris has a massive atmosphere filled with water vapor and methane, creating stunning auroras at its poles.",\n      "size": 120000,\n      "population": 0,\n      "distance_from_sun": 500\n    },\n    {\n      "name": "Veridion",\n      "description": "A lush, Earth-like planet with extensive forests and vast oceans, Veridion is home to intelligent life and has a rich cultural diversity.",\n      "size": 11000,\n      "population": 800000000,\n      "distance_from_sun": 0.9\n    },\n    {\n      "name": "Pyrona",\n      "description": "A rocky planet with volcanic activity, Pyrona has a thin atmosphere and is known for its extreme temperatures and geysers that erupt with superheated water and minerals.",\n      "size": 8000,\n      "population": 150000,\n      "distance_from_sun": 1.2\n    },\n    {\n      "name": "Cryos",\n      "description": "An icy world covered in frost and ice, Cryos has a thin atmosphere and is home to subterranean life forms that thrive in the dark environments.",\n      "size": 6000,\n      "population": 5000,\n      "distance_from_sun": 2.5\n    },\n    {\n      "name": "Zephyra",\n      "description": "A small, rocky planet with a dense atmosphere, Zephyra is a gas giant\'s moon and has a surface covered in deep craters and lava flows.",\n      "size": 4000,\n      "population": 0,\n      "distance_from_sun": 0.7\n    },\n    {\n      "name": "Elysium B",\n      "description": "A desert planet with towering sand dunes and occasional oases, Elysium B is a harsh environment but has a unique ecosystem of extremophiles.",\n      "size": 7000,\n      "population": 10000,\n      "distance_from_sun": 1.8\n    }\n  ],\n  "central_star": {\n    "name": "Solara",\n    "description": "A bright, blue-white star that emits a unique spectrum of light, Solara is a B-type main-sequence star with high energy output and a moderate size, influencing the atmospheric compositions of its surrounding planets.",\n    "size": 150000,\n    "temperature": 7500,\n    "radius": 1100\n  }\n}'}]]
